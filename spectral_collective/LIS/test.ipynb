# %%
from manim import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-002cc46713e5> in <module>
# ----> 1 from manim import *
#
# ModuleNotFoundError: No module named 'manim'
